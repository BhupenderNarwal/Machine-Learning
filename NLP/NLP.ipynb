# %%
import nltk
nltk.download('punkt')
import re
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.tokenize import sent_tokenize
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.

# %%
TEXT = """Long years ago we made a tryst with destiny, and now the time comes when we shall redeem our
pledge, not wholly or in full measure, but very substantially. At the stroke of the midnight hour,
when the world sleeps, India will awake to life and freedom. A moment comes, which comes but
rarely in history, when we step out from the old to the new, when an age ends, and when the soul of
a nation, long suppressed, finds utterance. It is fitting that at this solemn moment, we take the
pledge of dedication to the service of India and her people and to the still larger cause of humanity.
At the dawn of history, India started on her unending quest, and trackless centuries are filled with
her striving and grandeur of her success and failures. Through good and ill fortune alike, she has
never lost sight of that quest, forgotten the ideals which gave her strength. We end today a period of
misfortunes and India discovers herself again. The achievement we celebrate today is but a step, an
opening of opportunity to the greater triumphs and achievements that await us. Are we brave
enough and wise enough to grasp this opportunity and accept the challenge of the future?
Freedom and power bring responsibility. The responsibility rests upon this Assembly, a sovereign
body representing the sovereign people of India. Before the birth of freedom, we have endured all
the pains of labour and our hearts are heavy with the memory of this sorrrow. Some of those pains
continue even now. Nevertheless, the past is over and it is the future that beckons us now.
And so we have to labour and to work, and to work hard, to give reality to our dreams. Those
dreams are for India, but they are also for the world, for all the nations and peoples are too closely
knit together today for any one of them to imagine that it can live apart. Peace is said to be
indivisible, so is freedom, so is prosperity now, and also is disaster in this one world that can no
longer be split into isolated fragments.
To the people of India, whose representatives we are, we make an appeal to join us with faith and
confidence in this great adventure. This is no time for petty and destructive criticism, no time for ill-
will or blaming others. We have to build the noble mansion of free India where all her children may
dwell."""

# %%
# TOKENIZATION

tokenized_word = word_tokenize (TEXT)
tokenized_word
# Out:
# ['Long',
#  'years',
#  'ago',
#  'we',
#  'made',
#  'a',
#  'tryst',
#  'with',
#  'destiny',
#  ',',
#  'and',
#  'now',
#  'the',
#  'time',
#  'comes',
#  'when',
#  'we',
#  'shall',
#  'redeem',
#  'our',
#  'pledge',
#  ',',
#  'not',
#  'wholly',
#  'or',
#  'in',
#  'full',
#  'measure',
#  ',',
#  'but',
#  'very',
#  'substantially',
#  '.',
#  'At',
#  'the',
#  'stroke',
#  'of',
#  'the',
#  'midnight',
#  'hour',
#  ',',
#  'when',
#  'the',
#  'world',
#  'sleeps',
#  ',',
#  'India',
#  'will',
#  'awake',
#  'to',
#  'life',
#  'and',
#  'freedom',
#  '.',
#  'A',
#  'moment',
#  'comes',
#  ',',
#  'which',
#  'comes',
#  'but',
#  'rarely',
#  'in',
#  'history',
#  ',',
#  'when',
#  'we',
#  'step',
#  'out',
#  'from',
#  'the',
#  'old',
#  'to',
#  'the',
#  'new',
#  ',',
#  'when',
#  'an',
#  'age',
#  'ends',
#  ',',
#  'and',
#  'when',
#  'the',
#  'soul',
#  'of',
#  'a',
#  'nation',
#  ',',
#  'long',
#  'suppressed',
#  ',',
#  'finds',
#  'utterance',
#  '.',
#  'It',
#  'is',
#  'fitting',
#  'that',
#  'at',
#  'this',
#  'solemn',
#  'moment',
#  ',',
#  'we',
#  'take',
#  'the',
#  'pledge',
#  'of',
#  'dedication',
#  'to',
#  'the',
#  'service',
#  'of',
#  'India',
#  'and',
#  'her',
#  'people',
#  'and',
#  'to',
#  'the',
#  'still',
#  'larger',
#  'cause',
#  'of',
#  'humanity',
#  '.',
#  'At',
#  'the',
#  'dawn',
#  'of',
#  'history',
#  ',',
#  'India',
#  'started',
#  'on',
#  'her',
#  'unending',
#  'quest',
#  ',',
#  'and',
#  'trackless',
#  'centuries',
#  'are',
#  'filled',
#  'with',
#  'her',
#  'striving',
#  'and',
#  'grandeur',
#  'of',
#  'her',
#  'success',
#  'and',
#  'failures',
#  '.',
#  'Through',
#  'good',
#  'and',
#  'ill',
#  'fortune',
#  'alike',
#  ',',
#  'she',
#  'has',
#  'never',
#  'lost',
#  'sight',
#  'of',
#  'that',
#  'quest',
#  ',',
#  'forgotten',
#  'the',
#  'ideals',
#  'which',
#  'gave',
#  'her',
#  'strength',
#  '.',
#  'We',
#  'end',
#  'today',
#  'a',
#  'period',
#  'of',
#  'misfortunes',
#  'and',
#  'India',
#  'discovers',
#  'herself',
#  'again',
#  '.',
#  'The',
#  'achievement',
#  'we',
#  'celebrate',
#  'today',
#  'is',
#  'but',
#  'a',
#  'step',
#  ',',
#  'an',
#  'opening',
#  'of',
#  'opportunity',
#  'to',
#  'the',
#  'greater',
#  'triumphs',
#  'and',
#  'achievements',
#  'that',
#  'await',
#  'us',
#  '.',
#  'Are',
#  'we',
#  'brave',
#  'enough',
#  'and',
#  'wise',
#  'enough',
#  'to',
#  'grasp',
#  'this',
#  'opportunity',
#  'and',
#  'accept',
#  'the',
#  'challenge',
#  'of',
#  'the',
#  'future',
#  '?',
#  'Freedom',
#  'and',
#  'power',
#  'bring',
#  'responsibility',
#  '.',
#  'The',
#  'responsibility',
#  'rests',
#  'upon',
#  'this',
#  'Assembly',
#  ',',
#  'a',
#  'sovereign',
#  'body',
#  'representing',
#  'the',
#  'sovereign',
#  'people',
#  'of',
#  'India',
#  '.',
#  'Before',
#  'the',
#  'birth',
#  'of',
#  'freedom',
#  ',',
#  'we',
#  'have',
#  'endured',
#  'all',
#  'the',
#  'pains',
#  'of',
#  'labour',
#  'and',
#  'our',
#  'hearts',
#  'are',
#  'heavy',
#  'with',
#  'the',
#  'memory',
#  'of',
#  'this',
#  'sorrrow',
#  '.',
#  'Some',
#  'of',
#  'those',
#  'pains',
#  'continue',
#  'even',
#  'now',
#  '.',
#  'Nevertheless',
#  ',',
#  'the',
#  'past',
#  'is',
#  'over',
#  'and',
#  'it',
#  'is',
#  'the',
#  'future',
#  'that',
#  'beckons',
#  'us',
#  'now',
#  '.',
#  'And',
#  'so',
#  'we',
#  'have',
#  'to',
#  'labour',
#  'and',
#  'to',
#  'work',
#  ',',
#  'and',
#  'to',
#  'work',
#  'hard',
#  ',',
#  'to',
#  'give',
#  'reality',
#  'to',
#  'our',
#  'dreams',
#  '.',
#  'Those',
#  'dreams',
#  'are',
#  'for',
#  'India',
#  ',',
#  'but',
#  'they',
#  'are',
#  'also',
#  'for',
#  'the',
#  'world',
#  ',',
#  'for',
#  'all',
#  'the',
#  'nations',
#  'and',
#  'peoples',
#  'are',
#  'too',
#  'closely',
#  'knit',
#  'together',
#  'today',
#  'for',
#  'any',
#  'one',
#  'of',
#  'them',
#  'to',
#  'imagine',
#  'that',
#  'it',
#  'can',
#  'live',
#  'apart',
#  '.',
#  'Peace',
#  'is',
#  'said',
#  'to',
#  'be',
#  'indivisible',
#  ',',
#  'so',
#  'is',
#  'freedom',
#  ',',
#  'so',
#  'is',
#  'prosperity',
#  'now',
#  ',',
#  'and',
#  'also',
#  'is',
#  'disaster',
#  'in',
#  'this',
#  'one',
#  'world',
#  'that',
#  'can',
#  'no',
#  'longer',
#  'be',
#  'split',
#  'into',
#  'isolated',
#  'fragments',
#  '.',
#  'To',
#  'the',
#  'people',
#  'of',
#  'India',
#  ',',
#  'whose',
#  'representatives',
#  'we',
#  'are',
#  ',',
#  'we',
#  'make',
#  'an',
#  'appeal',
#  'to',
#  'join',
#  'us',
#  'with',
#  'faith',
#  'and',
#  'confidence',
#  'in',
#  'this',
#  'great',
#  'adventure',
#  '.',
#  'This',
#  'is',
#  'no',
#  'time',
#  'for',
#  'petty',
#  'and',
#  'destructive',
#  'criticism',
#  ',',
#  'no',
#  'time',
#  'for',
#  'ill-',
#  'will',
#  'or',
#  'blaming',
#  'others',
#  '.',
#  'We',
#  'have',
#  'to',
#  'build',
#  'the',
#  'noble',
#  'mansion',
#  'of',
#  'free',
#  'India',
#  'where',
#  'all',
#  'her',
#  'children',
#  'may',
#  'dwell',
#  '.']

# %%
tokenized_sent = sent_tokenize (TEXT)
tokenized_sent
# Out:
# ['Long years ago we made a tryst with destiny, and now the time comes when we shall redeem our\npledge, not wholly or in full measure, but very substantially.',
#  'At the stroke of the midnight hour,\nwhen the world sleeps, India will awake to life and freedom.',
#  'A moment comes, which comes but\nrarely in history, when we step out from the old to the new, when an age ends, and when the soul of\na nation, long suppressed, finds utterance.',
#  'It is fitting that at this solemn moment, we take the\npledge of dedication to the service of India and her people and to the still larger cause of humanity.',
#  'At the dawn of history, India started on her unending quest, and trackless centuries are filled with\nher striving and grandeur of her success and failures.',
#  'Through good and ill fortune alike, she has\nnever lost sight of that quest, forgotten the ideals which gave her strength.',
#  'We end today a period of\nmisfortunes and India discovers herself again.',
#  'The achievement we celebrate today is but a step, an\nopening of opportunity to the greater triumphs and achievements that await us.',
#  'Are we brave\nenough and wise enough to grasp this opportunity and accept the challenge of the future?',
#  'Freedom and power bring responsibility.',
#  'The responsibility rests upon this Assembly, a sovereign\nbody representing the sovereign people of India.',
#  'Before the birth of freedom, we have endured all\nthe pains of labour and our hearts are heavy with the memory of this sorrrow.',
#  'Some of those pains\ncontinue even now.',
#  'Nevertheless, the past is over and it is the future that beckons us now.',
#  'And so we have to labour and to work, and to work hard, to give reality to our dreams.',
#  'Those\ndreams are for India, but they are also for the world, for all the nations and peoples are too closely\nknit together today for any one of them to imagine that it can live apart.',
#  'Peace is said to be\nindivisible, so is freedom, so is prosperity now, and also is disaster in this one world that can no\nlonger be split into isolated fragments.',
#  'To the people of India, whose representatives we are, we make an appeal to join us with faith and\nconfidence in this great adventure.',
#  'This is no time for petty and destructive criticism, no time for ill-\nwill or blaming others.',
#  'We have to build the noble mansion of free India where all her children may\ndwell.']

# %%
import nltk
nltk.download("stopwords")
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# True

# %%
tokens_without_sw = [word for word in tokenized_word if not word in stopwords.words()]

# %%
print(tokens_without_sw)
# Out:
# ['Long', 'years', 'ago', 'made', 'tryst', 'destiny', ',', 'time', 'redeem', 'pledge', ',', 'wholly', 'full', 'measure', ',', 'substantially', '.', 'At', 'stroke', 'midnight', 'hour', ',', 'world', 'sleeps', ',', 'India', 'awake', 'life', 'freedom', '.', 'A', 'moment', ',', 'rarely', 'history', ',', 'step', ',', 'age', 'ends', ',', 'soul', 'nation', ',', 'long', 'suppressed', ',', 'finds', 'utterance', '.', 'It', 'fitting', 'solemn', 'moment', ',', 'pledge', 'dedication', 'service', 'India', 'larger', 'humanity', '.', 'At', 'dawn', 'history', ',', 'India', 'started', 'unending', 'quest', ',', 'trackless', 'centuries', 'filled', 'striving', 'grandeur', 'success', 'failures', '.', 'Through', 'fortune', 'alike', ',', 'lost', 'sight', 'quest', ',', 'forgotten', 'ideals', 'gave', 'strength', '.', 'We', 'today', 'period', 'misfortunes', 'India', 'discovers', '.', 'The', 'achievement', 'celebrate', 'today', 'step', ',', 'opening', 'opportunity', 'greater', 'triumphs', 'achievements', 'await', '.', 'Are', 'brave', 'wise', 'grasp', 'opportunity', 'accept', 'challenge', 'future', '?', 'Freedom', 'power', 'bring', 'responsibility', '.', 'The', 'responsibility', 'rests', 'Assembly', ',', 'sovereign', 'body', 'representing', 'sovereign', 'India', '.', 'Before', 'birth', 'freedom', ',', 'endured', 'pains', 'labour', 'hearts', 'heavy', 'memory', 'sorrrow', '.', 'Some', 'pains', 'continue', '.', 'Nevertheless', ',', 'past', 'future', 'beckons', '.', 'And', 'labour', 'work', ',', 'work', 'hard', ',', 'give', 'reality', 'dreams', '.', 'Those', 'dreams', 'India', ',', 'world', ',', 'nations', 'peoples', 'closely', 'knit', 'today', 'imagine', 'live', '.', 'Peace', 'indivisible', ',', 'freedom', ',', 'prosperity', ',', 'disaster', 'world', 'longer', 'split', 'isolated', 'fragments', '.', 'To', 'India', ',', 'representatives', ',', 'make', 'appeal', 'join', 'faith', 'confidence', 'great', 'adventure', '.', 'This', 'time', 'petty', 'destructive', 'criticism', ',', 'time', 'ill-', 'blaming', '.', 'We', 'build', 'noble', 'mansion', 'free', 'India', 'children', 'dwell', '.']

# %%
# Stemming

from nltk.stem import PorterStemmer
ps = PorterStemmer()

for i in tokenized_word:
    print(i,":",ps.stem(i))
# Out:
# Long : long
# years : year
# ago : ago
# we : we
# made : made
# a : a
# tryst : tryst
# with : with
# destiny : destini
# , : ,
# and : and
# now : now
# the : the
# time : time
# comes : come
# when : when
# we : we
# shall : shall
# redeem : redeem
# our : our
# pledge : pledg
# , : ,
# not : not
# wholly : wholli
# or : or
# in : in
# full : full
# measure : measur
# , : ,
# but : but
# very : veri
# substantially : substanti
# . : .
# At : at
# the : the
# stroke : stroke
# of : of
# the : the
# midnight : midnight
# hour : hour
# , : ,
# when : when
# the : the
# world : world
# sleeps : sleep
# , : ,
# India : india
# will : will
# awake : awak
# to : to
# life : life
# and : and
# freedom : freedom
# . : .
# A : a
# moment : moment
# comes : come
# , : ,
# which : which
# comes : come
# but : but
# rarely : rare
# in : in
# history : histori
# , : ,
# when : when
# we : we
# step : step
# out : out
# from : from
# the : the
# old : old
# to : to
# the : the
# new : new
# , : ,
# when : when
# an : an
# age : age
# ends : end
# , : ,
# and : and
# when : when
# the : the
# soul : soul
# of : of
# a : a
# nation : nation
# , : ,
# long : long
# suppressed : suppress
# , : ,
# finds : find
# utterance : utter
# . : .
# It : it
# is : is
# fitting : fit
# that : that
# at : at
# this : thi
# solemn : solemn
# moment : moment
# , : ,
# we : we
# take : take
# the : the
# pledge : pledg
# of : of
# dedication : dedic
# to : to
# the : the
# service : servic
# of : of
# India : india
# and : and
# her : her
# people : peopl
# and : and
# to : to
# the : the
# still : still
# larger : larger
# cause : caus
# of : of
# humanity : human
# . : .
# At : at
# the : the
# dawn : dawn
# of : of
# history : histori
# , : ,
# India : india
# started : start
# on : on
# her : her
# unending : unend
# quest : quest
# , : ,
# and : and
# trackless : trackless
# centuries : centuri
# are : are
# filled : fill
# with : with
# her : her
# striving : strive
# and : and
# grandeur : grandeur
# of : of
# her : her
# success : success
# and : and
# failures : failur
# . : .
# Through : through
# good : good
# and : and
# ill : ill
# fortune : fortun
# alike : alik
# , : ,
# she : she
# has : ha
# never : never
# lost : lost
# sight : sight
# of : of
# that : that
# quest : quest
# , : ,
# forgotten : forgotten
# the : the
# ideals : ideal
# which : which
# gave : gave
# her : her
# strength : strength
# . : .
# We : we
# end : end
# today : today
# a : a
# period : period
# of : of
# misfortunes : misfortun
# and : and
# India : india
# discovers : discov
# herself : herself
# again : again
# . : .
# The : the
# achievement : achiev
# we : we
# celebrate : celebr
# today : today
# is : is
# but : but
# a : a
# step : step
# , : ,
# an : an
# opening : open
# of : of
# opportunity : opportun
# to : to
# the : the
# greater : greater
# triumphs : triumph
# and : and
# achievements : achiev
# that : that
# await : await
# us : us
# . : .
# Are : are
# we : we
# brave : brave
# enough : enough
# and : and
# wise : wise
# enough : enough
# to : to
# grasp : grasp
# this : thi
# opportunity : opportun
# and : and
# accept : accept
# the : the
# challenge : challeng
# of : of
# the : the
# future : futur
# ? : ?
# Freedom : freedom
# and : and
# power : power
# bring : bring
# responsibility : respons
# . : .
# The : the
# responsibility : respons
# rests : rest
# upon : upon
# this : thi
# Assembly : assembl
# , : ,
# a : a
# sovereign : sovereign
# body : bodi
# representing : repres
# the : the
# sovereign : sovereign
# people : peopl
# of : of
# India : india
# . : .
# Before : befor
# the : the
# birth : birth
# of : of
# freedom : freedom
# , : ,
# we : we
# have : have
# endured : endur
# all : all
# the : the
# pains : pain
# of : of
# labour : labour
# and : and
# our : our
# hearts : heart
# are : are
# heavy : heavi
# with : with
# the : the
# memory : memori
# of : of
# this : thi
# sorrrow : sorrrow
# . : .
# Some : some
# of : of
# those : those
# pains : pain
# continue : continu
# even : even
# now : now
# . : .
# Nevertheless : nevertheless
# , : ,
# the : the
# past : past
# is : is
# over : over
# and : and
# it : it
# is : is
# the : the
# future : futur
# that : that
# beckons : beckon
# us : us
# now : now
# . : .
# And : and
# so : so
# we : we
# have : have
# to : to
# labour : labour
# and : and
# to : to
# work : work
# , : ,
# and : and
# to : to
# work : work
# hard : hard
# , : ,
# to : to
# give : give
# reality : realiti
# to : to
# our : our
# dreams : dream
# . : .
# Those : those
# dreams : dream
# are : are
# for : for
# India : india
# , : ,
# but : but
# they : they
# are : are
# also : also
# for : for
# the : the
# world : world
# , : ,
# for : for
# all : all
# the : the
# nations : nation
# and : and
# peoples : peopl
# are : are
# too : too
# closely : close
# knit : knit
# together : togeth
# today : today
# for : for
# any : ani
# one : one
# of : of
# them : them
# to : to
# imagine : imagin
# that : that
# it : it
# can : can
# live : live
# apart : apart
# . : .
# Peace : peac
# is : is
# said : said
# to : to
# be : be
# indivisible : indivis
# , : ,
# so : so
# is : is
# freedom : freedom
# , : ,
# so : so
# is : is
# prosperity : prosper
# now : now
# , : ,
# and : and
# also : also
# is : is
# disaster : disast
# in : in
# this : thi
# one : one
# world : world
# that : that
# can : can
# no : no
# longer : longer
# be : be
# split : split
# into : into
# isolated : isol
# fragments : fragment
# . : .
# To : to
# the : the
# people : peopl
# of : of
# India : india
# , : ,
# whose : whose
# representatives : repres
# we : we
# are : are
# , : ,
# we : we
# make : make
# an : an
# appeal : appeal
# to : to
# join : join
# us : us
# with : with
# faith : faith
# and : and
# confidence : confid
# in : in
# this : thi
# great : great
# adventure : adventur
# . : .
# This : thi
# is : is
# no : no
# time : time
# for : for
# petty : petti
# and : and
# destructive : destruct
# criticism : critic
# , : ,
# no : no
# time : time
# for : for
# ill- : ill-
# will : will
# or : or
# blaming : blame
# others : other
# . : .
# We : we
# have : have
# to : to
# build : build
# the : the
# noble : nobl
# mansion : mansion
# of : of
# free : free
# India : india
# where : where
# all : all
# her : her
# children : children
# may : may
# dwell : dwell
# . : .

# %%
# LEMMITIZATION

import nltk
nltk.download('wordnet')
nltk.download('omw-1.4')
from nltk.stem import WordNetLemmatizer
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to /root/nltk_data...

# %%
lemmatizer = WordNetLemmatizer()
lemmatized_output = ' '.join([lemmatizer.lemmatize(w) for w in tokenized_word])
print(lemmatized_output)
# Out:
# Long year ago we made a tryst with destiny , and now the time come when we shall redeem our pledge , not wholly or in full measure , but very substantially . At the stroke of the midnight hour , when the world sleep , India will awake to life and freedom . A moment come , which come but rarely in history , when we step out from the old to the new , when an age end , and when the soul of a nation , long suppressed , find utterance . It is fitting that at this solemn moment , we take the pledge of dedication to the service of India and her people and to the still larger cause of humanity . At the dawn of history , India started on her unending quest , and trackless century are filled with her striving and grandeur of her success and failure . Through good and ill fortune alike , she ha never lost sight of that quest , forgotten the ideal which gave her strength . We end today a period of misfortune and India discovers herself again . The achievement we celebrate today is but a step , an opening of opportunity to the greater triumph and achievement that await u . Are we brave enough and wise enough to grasp this opportunity and accept the challenge of the future ? Freedom and power bring responsibility . The responsibility rest upon this Assembly , a sovereign body representing the sovereign people of India . Before the birth of freedom , we have endured all the pain of labour and our heart are heavy with the memory of this sorrrow . Some of those pain continue even now . Nevertheless , the past is over and it is the future that beckons u now . And so we have to labour and to work , and to work hard , to give reality to our dream . Those dream are for India , but they are also for the world , for all the nation and people are too closely knit together today for any one of them to imagine that it can live apart . Peace is said to be indivisible , so is freedom , so is prosperity now , and also is disaster in this one world that can no longer be split into isolated fragment . To the people of India , whose representative we are , we make an appeal to join u with faith and confidence in this great adventure . This is no time for petty and destructive criticism , no time for ill- will or blaming others . We have to build the noble mansion of free India where all her child may dwell .

# %%
# WORD CLOUD

import pandas as pd
import matplotlib.pyplot as plt 
from wordcloud import WordCloud

# %%
from wordcloud import WordCloud, STOPWORDS
import matplotlib.pyplot as plt
import pandas as pd

comment_words = ''
stopwords = set(STOPWORDS)
 
# iterate through the csv file
for val in tokenized_word:
     
    # typecaste each val to string
    val = str(val)
 
    # split the value
    tokens = val.split()
     
    # Converts each token into lowercase
    for i in range(len(tokens)):
        tokens[i] = tokens[i].lower()
     
    comment_words += " ".join(tokens)+" "
 
wordcloud = WordCloud(width = 800, height = 800,
                background_color ='white',
                stopwords = stopwords,
                min_font_size = 10).generate(comment_words)
 
# plot the WordCloud image                      
plt.figure(figsize = (12, 12), facecolor = None)
plt.imshow(wordcloud)
plt.axis("off")
plt.tight_layout(pad = 0)
 
plt.show()

# %%
#TF IDF Vectorization

from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.feature_extraction.text import CountVectorizer
import pandas as pd

# %%
vectorizer = TfidfVectorizer()
tfidf_vector = vectorizer.fit_transform(tokenized_sent)

print(vectorizer.idf_)
# Out:
# [3.35137526 3.35137526 3.35137526 3.35137526 3.35137526 3.35137526
#  3.35137526 3.35137526 2.65822808 2.94591015 2.65822808 1.15415068
#  3.35137526 3.35137526 3.35137526 2.25276297 3.35137526 2.65822808
#  3.35137526 3.35137526 3.35137526 3.35137526 3.35137526 3.35137526
#  3.35137526 3.35137526 3.35137526 3.35137526 3.35137526 2.43508453
#  2.94591015 3.35137526 3.35137526 3.35137526 3.35137526 3.35137526
#  3.35137526 2.94591015 3.35137526 3.35137526 3.35137526 3.35137526
#  3.35137526 3.35137526 3.35137526 3.35137526 3.35137526 2.94591015
#  3.35137526 3.35137526 3.35137526 3.35137526 3.35137526 3.35137526
#  3.35137526 3.35137526 3.35137526 3.35137526 3.35137526 2.94591015
#  3.35137526 3.35137526 3.35137526 3.35137526 2.43508453 3.35137526
#  3.35137526 2.94591015 3.35137526 3.35137526 3.35137526 3.35137526
#  3.35137526 3.35137526 3.35137526 3.35137526 3.35137526 2.65822808
#  3.35137526 3.35137526 2.43508453 3.35137526 2.94591015 3.35137526
#  3.35137526 3.35137526 2.94591015 3.35137526 2.43508453 1.84729786
#  3.35137526 3.35137526 2.25276297 3.35137526 2.65822808 3.35137526
#  3.35137526 2.94591015 3.35137526 3.35137526 3.35137526 2.94591015
#  3.35137526 3.35137526 3.35137526 3.35137526 3.35137526 3.35137526
#  3.35137526 3.35137526 3.35137526 3.35137526 2.94591015 3.35137526
#  3.35137526 3.35137526 3.35137526 3.35137526 2.94591015 3.35137526
#  3.35137526 2.43508453 1.33647224 3.35137526 3.35137526 2.94591015
#  3.35137526 2.94591015 2.94591015 3.35137526 2.65822808 3.35137526
#  3.35137526 2.94591015 3.35137526 3.35137526 2.65822808 3.35137526
#  3.35137526 3.35137526 2.94591015 3.35137526 3.35137526 2.94591015
#  3.35137526 3.35137526 3.35137526 3.35137526 3.35137526 2.94591015
#  3.35137526 3.35137526 3.35137526 3.35137526 3.35137526 3.35137526
#  3.35137526 2.94591015 3.35137526 3.35137526 3.35137526 3.35137526
#  3.35137526 3.35137526 3.35137526 2.94591015 3.35137526 3.35137526
#  3.35137526 3.35137526 3.35137526 3.35137526 3.35137526 3.35137526
#  2.09861229 1.33647224 3.35137526 3.35137526 1.9650809  2.94591015
#  3.35137526 2.94591015 1.64662716 2.65822808 3.35137526 3.35137526
#  3.35137526 3.35137526 3.35137526 3.35137526 3.35137526 2.65822808
#  3.35137526 3.35137526 1.64662716 2.65822808 3.35137526 2.94591015
#  3.35137526 3.35137526 2.94591015 3.35137526 2.43508453 3.35137526
#  2.65822808 3.35137526]
